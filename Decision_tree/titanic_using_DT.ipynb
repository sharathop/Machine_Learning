# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve, auc

# %%
data = pd.read_csv('Titanic-Dataset.csv')

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print(data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.histplot(data['Survived'])
plt.figure()
sns.countplot(x='Survived', hue ='Sex', data=data)
plt.figure()
plt.hist(data['Age'],bins =30)
plt.figure()
sns.scatterplot(x='Age', y='Fare', data=data)
plt.figure()
sns.boxplot(x='Survived', y='Age', data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
print(data['FamilySize'])

data['Sex']=data['Sex'].map({'male':0,'female':1})
print(data['Sex'])
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: FamilySize, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
f_s =data.groupby('FamilySize')['Survived'].mean()

f_s.plot(kind='bar')
# Out:
# <Axes: xlabel='FamilySize'>

# %%
X=data[['Pclass','Sex','Age','FamilySize','Fare','Embarked']]
Y=data['Survived']


X_train , X_test ,Y_train, Y_test =train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
print(data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FamilySize       0
# dtype: int64

# %%
num_cols =['Age','Fare', 'FamilySize']
cat_cols =['Pclass','Sex','Embarked']

# %%
num_pipeline =Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scalar',StandardScaler())
])

cat_pipeline=Pipeline([
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('encoder',OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer([
    ('num',num_pipeline,num_cols),
    ('cat',cat_pipeline,cat_cols)
])

# %%
model_pipeline =Pipeline([
    ('processing',preprocessor),
    ('model',DecisionTreeClassifier(max_depth=3,class_weight='balanced'))
])

# %%
model_pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('processing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scalar',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Fare',
#                                                    'FamilySize']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Pclass', 'Sex',
#                                                    'Embarked'])])),
#                 ('model',
#                  DecisionTreeClassifier(class_weight='balanced', max_depth=3))])

# %%
pred = model_pipeline.predict(X_test)
print("Accuracy:", accuracy_score(Y_test, pred))

cm =confusion_matrix(Y_test,pred)
print(cm)
# Out:
# Accuracy: 0.7988826815642458
# [[92 13]
#  [23 51]]

# %%
y_scores = model_pipeline.predict_proba(X_test)[:, 1]
print(y_scores)
fpr, tpr, thresholds = roc_curve(Y_test, y_scores)
roc_auc = auc(fpr, tpr)


plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], linestyle='--')  # random baseline

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Decision Tree (Titanic)")
plt.legend()
plt.show()
# Out:
# [0.18235156 0.18235156 0.18235156 0.9809008  0.70027529 0.9809008
#  0.70027529 0.18235156 0.70027529 0.9809008  0.44896859 0.18235156
#  0.07649897 0.18235156 0.18235156 0.9809008  0.44896859 0.70027529
#  0.18235156 0.44896859 0.18235156 0.44896859 0.70027529 0.18235156
#  0.18235156 0.18235156 0.44896859 0.18235156 0.19137931 0.70027529
#  0.18235156 0.70027529 0.44896859 0.70027529 0.18235156 0.18235156
#  0.44896859 0.70027529 0.9809008  0.18235156 0.18235156 0.18235156
#  0.18235156 0.18235156 0.70027529 0.18235156 0.18235156 0.18235156
#  0.18235156 0.44896859 0.70027529 0.9809008  0.18235156 0.44896859
#  0.18235156 0.9809008  0.18235156 0.9809008  0.9809008  0.70027529
#  0.18235156 0.9809008  0.9809008  0.44896859 0.18235156 0.9809008
#  0.18235156 0.18235156 0.18235156 0.9809008  0.9809008  0.9809008
#  0.44896859 0.9809008  0.18235156 0.18235156 0.70027529 0.9809008
#  0.9809008  0.70027529 0.18235156 0.9809008  0.9809008  0.18235156
#  0.44896859 0.44896859 0.9809008  0.9809008  0.44896859 0.18235156
#  0.18235156 0.07649897 0.44896859 0.18235156 0.18235156 0.18235156
#  0.44896859 0.18235156 0.9809008  0.18235156 0.44896859 0.18235156
#  0.9809008  0.18235156 0.18235156 0.18235156 0.9809008  0.44896859
#  0.18235156 0.44896859 0.9809008  0.18235156 0.9809008  0.44896859
#  0.44896859 0.18235156 0.44896859 0.18235156 0.9809008  0.07649897
#  0.18235156 0.9809008  0.9809008  1.         0.18235156 0.44896859
#  0.9809008  0.44896859 0.70027529 0.18235156 0.70027529 0.18235156
#  0.18235156 0.70027529 0.44896859 0.70027529 0.9809008  0.18235156
#  0.18235156 0.70027529 0.18235156 0.9809008  0.18235156 0.18235156
#  0.07649897 0.9809008  0.18235156 0.18235156 0.9809008  0.18235156
#  0.18235156 0.18235156 0.18235156 0.07649897 0.18235156 0.18235156
#  0.18235156 0.70027529 0.9809008  0.70027529 0.18235156 0.44896859
#  0.18235156 0.9809008  0.18235156 0.44896859 0.18235156 0.9809008
#  0.18235156 0.18235156 0.44896859 0.9809008  0.44896859 0.70027529
#  0.18235156 0.18235156 0.07649897 0.9809008  0.70027529]
# [0.         0.         0.03809524 0.12380952 0.27619048 0.28571429
#  0.96190476 1.        ]
# [0.         0.01351351 0.5        0.68918919 0.86486486 0.86486486
#  0.97297297 1.        ]
# 0.8463320463320464

# %%
print(len(set(y_scores)))
# Out:
# 7
